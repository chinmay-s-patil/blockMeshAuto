# %%
from mesh_data import MeshData
import json

jsonPath = r"/home/lavender/GithubRepos/BlockMeshAuto/Example Creation/bulletMesh4.json"

# %%
# Create MeshData instance
mesh_data = MeshData()

# Load the JSON file
with open(jsonPath, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Load data into MeshData
mesh_data.from_dict(data)

# %%
# Now you can access connections in multiple ways:

# 1. Access all connections as a dictionary
print("All connections:", mesh_data.connections)

# # 2. Iterate through connections
# for conn_id, conn_data in mesh_data.connections.items():
#     print(f"Connection {conn_id}: Point {conn_data['point1']} -> Point {conn_data['point2']}")

# # 3. Access a specific connection
# if "1" in mesh_data.connections:
#     conn = mesh_data.connections["1"]
#     print(f"Connection 1: {conn['point1']} to {conn['point2']}")

# # 4. Get the next available connection ID
# print(f"Next connection ID: {mesh_data.next_connection_id}")

# # 5. Access the raw JSON format connections from the loaded data
# print("Raw Connections from JSON:", data.get("Connections", {}))
# Out:
# All connections: {'1': {'point1': 1, 'point2': 2}, '2': {'point1': 1, 'point2': 4}, '5': {'point1': 7, 'point2': 8}, '8': {'point1': 2, 'point2': 3}, '9': {'point1': 3, 'point2': 11}, '10': {'point1': 10, 'point2': 11}, '11': {'point1': 9, 'point2': 10}, '12': {'point1': 8, 'point2': 9}, '14': {'point1': 4, 'point2': 7}, '15': {'point1': 4, 'point2': 12}, '16': {'point1': 5, 'point2': 7}, '17': {'point1': 8, 'point2': 14}, '18': {'point1': 8, 'point2': 13}, '19': {'point1': 1, 'point2': 15}, '20': {'point1': 2, 'point2': 16}, '21': {'point1': 3, 'point2': 17}, '22': {'point1': 4, 'point2': 18}, '23': {'point1': 7, 'point2': 19}, '24': {'point1': 8, 'point2': 20}, '25': {'point1': 9, 'point2': 21}, '26': {'point1': 10, 'point2': 22}, '27': {'point1': 11, 'point2': 23}, '28': {'point1': 5, 'point2': 24}, '29': {'point1': 12, 'point2': 25}, '30': {'point1': 13, 'point2': 26}, '31': {'point1': 14, 'point2': 27}, '32': {'point1': 15, 'point2': 16}, '33': {'point1': 15, 'point2': 18}, '34'
# ...

# %%
for conn_id, conn_data in list(mesh_data.connections.items()):
    print(conn_data)
    p1 = conn_data.get('point1')
    p2 = conn_data.get('point2')
    
    print(p1)
    print(p2)
# Out:
# {'point1': 1, 'point2': 2}
# 1
# 2
# {'point1': 1, 'point2': 4}
# 1
# 4
# {'point1': 7, 'point2': 8}
# 7
# 8
# {'point1': 2, 'point2': 3}
# 2
# 3
# {'point1': 3, 'point2': 11}
# 3
# 11
# {'point1': 10, 'point2': 11}
# 10
# 11
# {'point1': 9, 'point2': 10}
# 9
# 10
# {'point1': 8, 'point2': 9}
# 8
# 9
# {'point1': 4, 'point2': 7}
# 4
# 7
# {'point1': 4, 'point2': 12}
# 4
# 12
# {'point1': 5, 'point2': 7}
# 5
# 7
# {'point1': 8, 'point2': 14}
# 8
# 14
# {'point1': 8, 'point2': 13}
# 8
# 13
# {'point1': 1, 'point2': 15}
# 1
# 15
# {'point1': 2, 'point2': 16}
# 2
# 16
# {'point1': 3, 'point2': 17}
# 3
# 17
# {'point1': 4, 'point2': 18}
# 4
# 18
# {'point1': 7, 'point2': 19}
# 7
# 19
# {'point1': 8, 'point2': 20}
# 8
# 20
# {'point1': 9, 'point2': 21}
# 9
# 21
# {'point1': 10, 'point2': 22}
# 10
# 22
# {'point1': 11, 'point2': 23}
# 11
# 23
# {'point1': 5, 'point2': 24}
# 5
# 24
# {'point1': 12, 'point2': 25}
# 12
# 25
# {'point1': 13, 'point2': 26}
# 13
# 26
# ...

# %%
blockMeshPath = r"/home/lavender/GithubRepos/BlockMeshAuto/Code/blockMeshDict"

with open(blockMeshPath, 'r', encoding='utf-8') as f:
    blockMesh = f.readlines()
    
    end = 0
    
    for 
    

# [i.strip() for i in blockMesh]

# for line in blockMesh:
#     print(line, end="")
    
#     if "scale" in line:
#         print(line)
        
#     if "vertices" in line:
#         print(line)
# Out:
# /*--------------------------------*- C++ -*----------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v2412                                 |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       dictionary;
#     object      blockMeshDict;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
#
# scale   0.001;
# scale   0.001;
#
#
# vertices
# vertices
#
# (
#     ( 0          0          0 )		// 0
#     ( 5          0          0 )		// 1
#     ( 7.5        0.90992585 0 )		// 2
# ...
